# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import random

from keras import Sequential
from keras.layers import Conv2D, Dropout, MaxPool2D, Flatten, Dense, Convolution2D, LeakyReLU, BatchNormalization

model = Sequential()

model.add(Convolution2D(32, (3,3), padding='same', use_bias=False, input_shape=(96,96,1)))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(32, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())


model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(196))
model.summary()
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W1222 19:21:29.444599 12912 deprecation_wrapper.py:119] From c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1222 19:21:29.462722 12912 deprecation_wrapper.py:119] From c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1222 19:21:29.467714 12912 deprecation_wrapper.py:119] From c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
import os
import pandas as pd
path = "./data/train/"                           # 设置路径
dirs = os.listdir(path)                    # 获取指定路径下的文件

ptsFrame = [] # 总的坐标
index = 0

def readLmk(fileName):
    landmarks = []
    fileName = path + str(fileName)
    print(fileName)
    if not os.path.exists(fileName):
        return landmarks
    else:
        fp = open(fileName)
        for line in fp:
            xyLocal = line.split(",")
            landmarks.append(xyLocal[0])
            landmarks.append(xyLocal[1].strip())
    #ptsTmp = pd.DataFrame({str(index) : landmarks})
    # print(ptsTmp.T)
    # ptsTmp = ptsTmp.T
    ptsFrame.append(landmarks)
    return landmarks
    

for i in dirs: 
    if os.path.splitext(i)[1] == ".pts":   # 筛选csv文件
        readLmk(i)
        index += 1
ptsData = pd.DataFrame(ptsFrame)
print(ptsData.head())
ptsData.to_csv("pts.csv",index = True)
# Out:
# ./data/train/0000.pts
# ./data/train/0001.pts
# ./data/train/0002.pts
# ./data/train/0003.pts
# ./data/train/0004.pts
# ./data/train/0005.pts
# ./data/train/0006.pts
# ./data/train/0007.pts
# ./data/train/0008.pts
# ./data/train/0009.pts
# ./data/train/0010.pts
# ./data/train/0011.pts
# ./data/train/0012.pts
# ./data/train/0013.pts
# ./data/train/0014.pts
# ./data/train/0015.pts
# ./data/train/0016.pts
# ./data/train/0017.pts
# ./data/train/0018.pts
# ./data/train/0019.pts
# ./data/train/0020.pts
# ./data/train/0021.pts
# ./data/train/0022.pts
# ./data/train/0023.pts
# ./data/train/0024.pts
# ./data/train/0025.pts
# ./data/train/0026.pts
# ./data/train/0027.pts
# ./data/train/0028.pts
# ./data/train/0029.pts
# ./data/train/0030.pts
# ./data/train/0031.pts
# ./data/train/0032.pts
# ./data/train/0033.pts
# ./data/train/0034.pts
# ./data/train/0035.pts
# ./data/train/0036.pts
# ./data/train/0037.pts
# ./data/train/0038.pts
# ./data/train/0039.pts
# ./data/train/0040.pts
# ...
